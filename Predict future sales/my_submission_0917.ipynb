# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_rows',500)
pd.set_option('display.max_columns',100)

from itertools import product
from sklearn.preprocessing import LabelEncoder #对不连续的数字或文本编号

import seaborn as sns
import matplotlib.pyplot as plt

from xgboost import XGBRegressor
from xgboost import plot_importance

def plot_features(booster,figsize):
    fig,ax = plt.subplots(1,1,figsize=figsize)
    return plot_importance(booster=booster,ax=ax)

import time
import sys
import gc
import pickle
sys.version_info
# Out:
# sys.version_info(major=3, minor=6, micro=5, releaselevel='final', serial=0)

# %%
items = pd.read_csv('items.csv')
shops = pd.read_csv('shops.csv')
cats = pd.read_csv('item_categories.csv')
train = pd.read_csv('sales_train.csv')
test = pd.read_csv('test.csv').set_index('ID')

# %%
#异常值清洗

plt.figure(figsize=(10,4))
plt.xlim(-100,3000)
sns.boxplot(x=train.item_cnt_day)

# %%
plt.figure(figsize=(10,4))
plt.xlim(train.item_price.min(),train.item_price.max()*1.1)
sns.boxplot(x=train.item_price)

# %%
train = train[train.item_price<100000]
train = train[train.item_cnt_day<1001]

# %%
median = train[(train.shop_id==32)&(train.item_id==2973)&(train.date_block_num==4)&(train.item_price>0)].item_price.median()
train.loc[train.item_price<0, 'item_price'] = median

# %%
train.loc[train.shop_id == 0, 'shop_id'] = 57
test.loc[test.shop_id == 0, 'shop_id'] = 57
# Якутск ТЦ "Центральный"
train.loc[train.shop_id == 1, 'shop_id'] = 58
test.loc[test.shop_id == 1, 'shop_id'] = 58
# Жуковский ул. Чкалова 39м²
train.loc[train.shop_id == 10, 'shop_id'] = 11
test.loc[test.shop_id == 10, 'shop_id'] = 11

# %%
shops.head()
# Out:
#                         shop_name  shop_id
# 0   !Якутск Орджоникидзе, 56 фран        0
# 1   !Якутск ТЦ "Центральный" фран        1
# 2                Адыгея ТЦ "Мега"        2
# 3  Балашиха ТРК "Октябрь-Киномир"        3
# 4        Волжский ТЦ "Волга Молл"        4

# %%
shops.loc[shops.shop_name == 'Сергиев Посад ТЦ "7Я"', 'shop_name'] = 'СергиевПосад ТЦ "7Я"'
shops['city'] = shops['shop_name'].str.split(' ').map(lambda x: x[0])
shops.loc[shops.city == '!Якутск', 'city'] = 'Якутск'
shops['city_code'] = LabelEncoder().fit_transform(shops['city'])
shops = shops[['shop_id','city_code']]
shops.head()
# Out:
#    shop_id  city_code
# 0        0         29
# 1        1         29
# 2        2          0
# 3        3          1
# 4        4          2

# %%
cats['split'] = cats['item_category_name'].str.split('-')
cats['type'] = cats['split'].map(lambda x: x[0].strip())
cats['type_code'] = LabelEncoder().fit_transform(cats['type'])
# if subtype is nan then type
cats['subtype'] = cats['split'].map(lambda x: x[1].strip() if len(x) > 1 else x[0].strip())
cats['subtype_code'] = LabelEncoder().fit_transform(cats['subtype'])
cats = cats[['item_category_id','type_code', 'subtype_code']]

items.drop(['item_name'], axis=1, inplace=True)
cats.head()
# Out:
#    item_category_id  type_code  subtype_code
# 0                 0          0            29
# 1                 1          1             9
# 2                 2          1            10
# 3                 3          1            11
# 4                 4          1            13

# %%
ts = time.time()
matrix = []
cols = ['date_block_num','shop_id','item_id']
for i in range(34):
    sales = train[train.date_block_num==i]
    matrix.append(np.array(list(product([i], sales.shop_id.unique(), sales.item_id.unique())), dtype='int16'))
    
matrix = pd.DataFrame(np.vstack(matrix), columns=cols)
matrix['date_block_num'] = matrix['date_block_num'].astype(np.int8)
matrix['shop_id'] = matrix['shop_id'].astype(np.int8)
matrix['item_id'] = matrix['item_id'].astype(np.int16)
matrix.sort_values(cols,inplace=True)
matrix.head()
# Out:
#         date_block_num  shop_id  item_id
# 114910               0        2       19
# 117150               0        2       27
# 120623               0        2       28
# 118316               0        2       29
# 114602               0        2       32

# %%
train['revenue'] = train['item_price'] *  train['item_cnt_day']

# %%
ts = time.time()
group = train.groupby(['date_block_num','shop_id','item_id']).agg({'item_cnt_day': ['sum']})
group.columns = ['item_cnt_month']
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=cols, how='left')
matrix['item_cnt_month'] = (matrix['item_cnt_month']
                                .fillna(0)
                                .clip(0,20) # NB clip target here
                                .astype(np.float16))

group.head()
# Out:
#    date_block_num  shop_id  item_id  item_cnt_month
# 0               0        2       27             1.0
# 1               0        2       33             1.0
# 2               0        2      317             1.0
# 3               0        2      438             1.0
# 4               0        2      471             2.0

# %%
test['date_block_num'] = 34
test['date_block_num'] = test['date_block_num'].astype(np.int8)
test['shop_id'] = test['shop_id'].astype(np.int8)
test['item_id'] = test['item_id'].astype(np.int16)
test.head()
# Out:
#     shop_id  item_id  date_block_num
# ID
# 0         5     5037              34
# 1         5     5320              34
# 2         5     5233              34
# 3         5     5232              34
# 4         5     5268              34

# %%
ts = time.time()
matrix = pd.concat([matrix, test], ignore_index=True, sort=False, keys=cols)
matrix.fillna(0, inplace=True) # 34 month
matrix.head()
# Out:
#    date_block_num  shop_id  item_id  item_cnt_month
# 0               0        2       19             0.0
# 1               0        2       27             1.0
# 2               0        2       28             0.0
# 3               0        2       29             0.0
# 4               0        2       32             0.0

# %%
ts = time.time()
matrix = pd.merge(matrix, shops, on=['shop_id'], how='left')
matrix = pd.merge(matrix, items, on=['item_id'], how='left')
matrix = pd.merge(matrix, cats, on=['item_category_id'], how='left')
matrix['city_code'] = matrix['city_code'].astype(np.int8)
matrix['item_category_id'] = matrix['item_category_id'].astype(np.int8)
matrix['type_code'] = matrix['type_code'].astype(np.int8)
matrix['subtype_code'] = matrix['subtype_code'].astype(np.int8)
matrix.head()
# Out:
#    date_block_num  shop_id  item_id  item_cnt_month  city_code  \
# 0               0        2       19             0.0          0
# 1               0        2       27             1.0          0
# 2               0        2       28             0.0          0
# 3               0        2       29             0.0          0
# 4               0        2       32             0.0          0
#
#    item_category_id  type_code  subtype_code
# 0                40         11             4
# 1                19          5            10
# 2                30          8            55
# 3                23          5            16
# 4                40         11             4

# %%
matrix.head().append(matrix.tail())
# Out:
#           date_block_num  shop_id  item_id  item_cnt_month  city_code  \
# 0                      0        2       19             0.0          0
# 1                      0        2       27             1.0          0
# 2                      0        2       28             0.0          0
# 3                      0        2       29             0.0          0
# 4                      0        2       32             0.0          0
# 11127999              34       45    18454             0.0         20
# 11128000              34       45    16188             0.0         20
# 11128001              34       45    15757             0.0         20
# 11128002              34       45    19648             0.0         20
# 11128003              34       45      969             0.0         20
#
#           item_category_id  type_code  subtype_code
# 0                       40         11             4
# 1                       19          5            10
# 2                       30          8            55
# 3                       23          5            16
# 4                       40         11             4
# 11127999                55         13             2
# 11128000                64         14            42
# 11128001                55         13             2
# 11128002                40         11             4
# 11128003                37         11             1

# %%
data = matrix

# %%
X_train = data[data.date_block_num < 33].drop(['item_cnt_month'], axis=1)
Y_train = data[data.date_block_num < 33]['item_cnt_month']
X_valid = data[data.date_block_num == 33].drop(['item_cnt_month'], axis=1)
Y_valid = data[data.date_block_num == 33]['item_cnt_month']
X_test = data[data.date_block_num == 34].drop(['item_cnt_month'], axis=1)

# %%
model = XGBRegressor(
    max_depth=8,
    n_estimators=1000,
    min_child_weight=300, 
    colsample_bytree=0.8, 
    subsample=0.8, 
    eta=0.3,    
    seed=42)

model.fit(
    X_train, 
    Y_train, 
    eval_metric="rmse", 
    eval_set=[(X_train, Y_train), (X_valid, Y_valid)], 
    verbose=True, 
    early_stopping_rounds = 10)
# Out:
# /Users/luhuiyang/anaconda3/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# /Users/luhuiyang/anaconda3/lib/python3.6/site-packages/xgboost/core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \
# [21:42:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:42:37] WARNING: src/learner.cc:686: Tree method is automatically selected to be 'approx' for faster speed. To use old behavior (exact greedy algorithm on single machine), set tree_method to 'exact'.
# [0]	validation_0-rmse:1.16881	validation_1-rmse:1.14775
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 10 rounds.
# [1]	validation_0-rmse:1.16416	validation_1-rmse:1.13444
# [2]	validation_0-rmse:1.16007	validation_1-rmse:1.12232
# [3]	validation_0-rmse:1.15748	validation_1-rmse:1.11385
# [4]	validation_0-rmse:1.14794	validation_1-rmse:1.10237
# [5]	validation_0-rmse:1.14234	validation_1-rmse:1.09667
# [6]	validation_0-rmse:1.13946	validation_1-rmse:1.09001
# [7]	validation_0-rmse:1.13781	validation_1-rmse:1.08575
# [8]	validation_0-rmse:1.13877	validation_1-rmse:1.08201
# [9]	validation_0-rmse:1.13683	validation_1-rmse:1.07887
# [10]	validation_0-rmse:1.13614	validation_1-rmse:1.07571
# [11]	validation_0-rmse:1.13457	validation_1-rmse:1.07341
# [12]	validation_0-rmse:1.13298	validation_1-rmse:1.07128
# [13]	validation_0-rmse:1.12873	validation_1-rmse:1.06484
# [14]	validation_0-rmse:1.12614	validation_1-rmse:1.06032
# [15]	validation_0-rmse:1.1253	validation_1-rmse:1.05816
# [16]	validation_0-rmse:1.12325	validation_1-rmse:1.05556
# [17]	validation_0-rmse:1.12125	validation_1-rmse:1.05286
# [18]	validation_0-rmse:1.11931	validation_1-rmse:1.05081
# [19]	validation_0-rmse:1.11876	validation_1-rmse:1.04981
# [20]	validation_0-rmse:1.11709	validation_1-rmse:1.04753
# [21]	validation_0-rmse:1.11619	validation_1-rmse:1.04615
# [22]	validation_0-rmse:1.11477	validation_1-rmse:1.04457
# [23]	validation_0-rmse:1.11316	validation_1-rmse:1.04208
# [24]	validation_0-rmse:1.1118	validation_1-rmse:1.04078
# [25]	validation_0-rmse:1.11131	validation_1-rmse:1.0404
# [26]	validation_0-rmse:1.11032	validation_1-rmse:1.03971
# [27]	validation_0-rmse:1.10991	validation_1-rmse:1.03902
# [28]	validation_0-rmse:1.109	validation_1-rmse:1.03821
# [29]	validation_0-rmse:1.10828	validation_1-rmse:1.03725
# [30]	validation_0-rmse:1.10722	validation_1-rmse:1.03627
# [31]	validation_0-rmse:1.10685	validation_1-rmse:1.03569
# [32]	validation_0-rmse:1.10595	validation_1-rmse:1.03444
# [33]	validation_0-rmse:1.10544	validation_1-rmse:1.03379
# [34]	validation_0-rmse:1.10516	validation_1-rmse:1.0335
# [35]	validation_0-rmse:1.10441	validation_1-rmse:1.03275
# [36]	validation_0-rmse:1.10406	validation_1-rmse:1.03248
# [37]	validation_0-rmse:1.10395	validation_1-rmse:1.03252
# [38]	validation_0-rmse:1.10363	validation_1-rmse:1.0324
# [39]	validation_0-rmse:1.10309	validation_1-rmse:1.03186
# [40]	validation_0-rmse:1.10261	validation_1-rmse:1.03154
# [41]	validation_0-rmse:1.10233	validation_1-rmse:1.03041
# [42]	validation_0-rmse:1.10202	validation_1-rmse:1.03012
# [43]	validation_0-rmse:1.10177	validation_1-rmse:1.02988
# [44]	validation_0-rmse:1.10149	validation_1-rmse:1.02947
# [45]	validation_0-rmse:1.10117	validation_1-rmse:1.02857
# [46]	validation_0-rmse:1.10066	validation_1-rmse:1.02805
# [47]	validation_0-rmse:1.1003	validation_1-rmse:1.02698
# [48]	validation_0-rmse:1.09999	validation_1-rmse:1.02677
# [49]	validation_0-rmse:1.09923	validation_1-rmse:1.02612
# [50]	validation_0-rmse:1.09898	validation_1-rmse:1.02574
# [51]	validation_0-rmse:1.09871	validation_1-rmse:1.02552
# [52]	validation_0-rmse:1.09847	validation_1-rmse:1.02534
# [53]	validation_0-rmse:1.09821	validation_1-rmse:1.02511
# [54]	validation_0-rmse:1.09804	validation_1-rmse:1.02492
# [55]	validation_0-rmse:1.09789	validation_1-rmse:1.02457
# [56]	validation_0-rmse:1.09755	validation_1-rmse:1.02455
# [57]	validation_0-rmse:1.09721	validation_1-rmse:1.02299
# [58]	validation_0-rmse:1.09673	validation_1-rmse:1.02259
# [59]	validation_0-rmse:1.09659	validation_1-rmse:1.02251
# [60]	validation_0-rmse:1.09646	validation_1-rmse:1.02164
# [61]	validation_0-rmse:1.09633	validation_1-rmse:1.0215
# [62]	validation_0-rmse:1.09593	validation_1-rmse:1.02116
# [63]	validation_0-rmse:1.09576	validation_1-rmse:1.02127
# [64]	validation_0-rmse:1.09557	validation_1-rmse:1.02122
# [65]	validation_0-rmse:1.09531	validation_1-rmse:1.02102
# [66]	validation_0-rmse:1.09519	validation_1-rmse:1.02092
# [67]	validation_0-rmse:1.09501	validation_1-rmse:1.02039
# [68]	validation_0-rmse:1.09495	validation_1-rmse:1.02035
# [69]	validation_0-rmse:1.09482	validation_1-rmse:1.02028
# [70]	validation_0-rmse:1.09472	validation_1-rmse:1.02024
# [71]	validation_0-rmse:1.09465	validation_1-rmse:1.0202
# [72]	validation_0-rmse:1.09439	validation_1-rmse:1.02006
# [73]	validation_0-rmse:1.09423	validation_1-rmse:1.01977
# [74]	validation_0-rmse:1.09398	validation_1-rmse:1.01958
# [75]	validation_0-rmse:1.09385	validation_1-rmse:1.01917
# [76]	validation_0-rmse:1.09376	validation_1-rmse:1.01902
# [77]	validation_0-rmse:1.09361	validation_1-rmse:1.01893
# [78]	validation_0-rmse:1.09354	validation_1-rmse:1.01891
# [79]	validation_0-rmse:1.09339	validation_1-rmse:1.01862
# [80]	validation_0-rmse:1.09285	validation_1-rmse:1.01856
# [81]	validation_0-rmse:1.09256	validation_1-rmse:1.01846
# [82]	validation_0-rmse:1.09243	validation_1-rmse:1.01833
# [83]	validation_0-rmse:1.09213	validation_1-rmse:1.01809
# [84]	validation_0-rmse:1.09206	validation_1-rmse:1.01778
# [85]	validation_0-rmse:1.09178	validation_1-rmse:1.01758
# [86]	validation_0-rmse:1.0917	validation_1-rmse:1.01754
# [87]	validation_0-rmse:1.09146	validation_1-rmse:1.01738
# [88]	validation_0-rmse:1.09128	validation_1-rmse:1.01734
# [89]	validation_0-rmse:1.09119	validation_1-rmse:1.01736
# [90]	validation_0-rmse:1.09095	validation_1-rmse:1.01733
# [91]	validation_0-rmse:1.09089	validation_1-rmse:1.01724
# [92]	validation_0-rmse:1.09048	validation_1-rmse:1.01703
# [93]	validation_0-rmse:1.09035	validation_1-rmse:1.01673
# [94]	validation_0-rmse:1.09027	validation_1-rmse:1.01669
# [95]	validation_0-rmse:1.09009	validation_1-rmse:1.01659
# [96]	validation_0-rmse:1.09	validation_1-rmse:1.01652
# [97]	validation_0-rmse:1.08947	validation_1-rmse:1.01596
# [98]	validation_0-rmse:1.08942	validation_1-rmse:1.01593
# [99]	validation_0-rmse:1.08922	validation_1-rmse:1.01587
# [100]	validation_0-rmse:1.08912	validation_1-rmse:1.01591
# [101]	validation_0-rmse:1.08899	validation_1-rmse:1.01585
# [102]	validation_0-rmse:1.08884	validation_1-rmse:1.01569
# [103]	validation_0-rmse:1.08871	validation_1-rmse:1.01563
# [104]	validation_0-rmse:1.08839	validation_1-rmse:1.01542
# [105]	validation_0-rmse:1.08821	validation_1-rmse:1.0153
# [106]	validation_0-rmse:1.08815	validation_1-rmse:1.01497
# [107]	validation_0-rmse:1.08811	validation_1-rmse:1.0148
# [108]	validation_0-rmse:1.08784	validation_1-rmse:1.01484
# [109]	validation_0-rmse:1.08772	validation_1-rmse:1.01481
# [110]	validation_0-rmse:1.08768	validation_1-rmse:1.01456
# [111]	validation_0-rmse:1.08754	validation_1-rmse:1.01451
# [112]	validation_0-rmse:1.08738	validation_1-rmse:1.01454
# [113]	validation_0-rmse:1.0872	validation_1-rmse:1.01442
# [114]	validation_0-rmse:1.08705	validation_1-rmse:1.01441
# [115]	validation_0-rmse:1.08697	validation_1-rmse:1.01432
# [116]	validation_0-rmse:1.08688	validation_1-rmse:1.01431
# [117]	validation_0-rmse:1.08685	validation_1-rmse:1.01409
# [118]	validation_0-rmse:1.08678	validation_1-rmse:1.01401
# [119]	validation_0-rmse:1.08665	validation_1-rmse:1.01378
# [120]	validation_0-rmse:1.08629	validation_1-rmse:1.01363
# [121]	validation_0-rmse:1.08623	validation_1-rmse:1.01364
# [122]	validation_0-rmse:1.0861	validation_1-rmse:1.01361
# [123]	validation_0-rmse:1.08599	validation_1-rmse:1.01349
# [124]	validation_0-rmse:1.08591	validation_1-rmse:1.01339
# [125]	validation_0-rmse:1.08564	validation_1-rmse:1.01306
# [126]	validation_0-rmse:1.08536	validation_1-rmse:1.01304
# [127]	validation_0-rmse:1.08519	validation_1-rmse:1.01301
# [128]	validation_0-rmse:1.08515	validation_1-rmse:1.01305
# [129]	validation_0-rmse:1.08507	validation_1-rmse:1.01314
# [130]	validation_0-rmse:1.085	validation_1-rmse:1.0132
# [131]	validation_0-rmse:1.08492	validation_1-rmse:1.01314
# [132]	validation_0-rmse:1.08485	validation_1-rmse:1.01315
# [133]	validation_0-rmse:1.08471	validation_1-rmse:1.01301
# [134]	validation_0-rmse:1.08456	validation_1-rmse:1.01293
# [135]	validation_0-rmse:1.08445	validation_1-rmse:1.01283
# [136]	validation_0-rmse:1.08442	validation_1-rmse:1.01278
# [137]	validation_0-rmse:1.08438	validation_1-rmse:1.01271
# [138]	validation_0-rmse:1.08418	validation_1-rmse:1.01294
# [139]	validation_0-rmse:1.08413	validation_1-rmse:1.01292
# [140]	validation_0-rmse:1.08402	validation_1-rmse:1.0129
# [141]	validation_0-rmse:1.08392	validation_1-rmse:1.01284
# [142]	validation_0-rmse:1.08376	validation_1-rmse:1.01281
# [143]	validation_0-rmse:1.08371	validation_1-rmse:1.01277
# [144]	validation_0-rmse:1.08343	validation_1-rmse:1.01264
# [145]	validation_0-rmse:1.08328	validation_1-rmse:1.01254
# [146]	validation_0-rmse:1.08298	validation_1-rmse:1.01255
# [147]	validation_0-rmse:1.08284	validation_1-rmse:1.01252
# [148]	validation_0-rmse:1.08278	validation_1-rmse:1.01248
# [149]	validation_0-rmse:1.08274	validation_1-rmse:1.01248
# [150]	validation_0-rmse:1.08247	validation_1-rmse:1.01192
# [151]	validation_0-rmse:1.08227	validation_1-rmse:1.01192
# [152]	validation_0-rmse:1.08223	validation_1-rmse:1.0123
# [153]	validation_0-rmse:1.08207	validation_1-rmse:1.01227
# [154]	validation_0-rmse:1.082	validation_1-rmse:1.01215
# [155]	validation_0-rmse:1.08192	validation_1-rmse:1.01197
# [156]	validation_0-rmse:1.08186	validation_1-rmse:1.01195
# [157]	validation_0-rmse:1.08183	validation_1-rmse:1.01192
# [158]	validation_0-rmse:1.08179	validation_1-rmse:1.01194
# [159]	validation_0-rmse:1.08171	validation_1-rmse:1.01191
# [160]	validation_0-rmse:1.08166	validation_1-rmse:1.01184
# [161]	validation_0-rmse:1.08159	validation_1-rmse:1.01181
# [162]	validation_0-rmse:1.08139	validation_1-rmse:1.01171
# [163]	validation_0-rmse:1.08125	validation_1-rmse:1.01205
# [164]	validation_0-rmse:1.08115	validation_1-rmse:1.01199
# [165]	validation_0-rmse:1.0811	validation_1-rmse:1.01191
# [166]	validation_0-rmse:1.08103	validation_1-rmse:1.01191
# [167]	validation_0-rmse:1.08096	validation_1-rmse:1.01209
# [168]	validation_0-rmse:1.08082	validation_1-rmse:1.01203
# [169]	validation_0-rmse:1.08075	validation_1-rmse:1.01203
# [170]	validation_0-rmse:1.0807	validation_1-rmse:1.01197
# [171]	validation_0-rmse:1.08065	validation_1-rmse:1.01193
# [172]	validation_0-rmse:1.08058	validation_1-rmse:1.01193
# Stopping. Best iteration:
# [162]	validation_0-rmse:1.08139	validation_1-rmse:1.01171
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=0.8, eta=0.3, gamma=0,
#        importance_type='gain', learning_rate=0.1, max_delta_step=0,
#        max_depth=8, min_child_weight=300, missing=None, n_estimators=1000,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=42, silent=None,
#        subsample=0.8, verbosity=1)

# %%
Y_pred = model.predict(X_valid).clip(0, 20)
Y_test = model.predict(X_test).clip(0, 20)

submission = pd.DataFrame({
    "ID": test.index, 
    "item_cnt_month": Y_test
})
submission.to_csv('xgb_submission_0917.csv', index=False)
